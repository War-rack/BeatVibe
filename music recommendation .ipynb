# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_millsongdata.csv")

# %%
df.describe()
# Out:
#               artist                                    song  \
# count          57650                                   57650
# unique           643                                   44824
# top     Donna Summer  Have Yourself A Merry Little Christmas
# freq             191                                      35
#
#                                               link  \
# count                                        57650
# unique                                       57650
# top     /a/abba/ahes+my+kind+of+girl_20598417.html
# freq                                             1
#
#                                                      text
# count                                               57650
# unique                                              57494
# top     I just came back from a lovely trip along the ...
# freq                                                    6

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(6)
# Out:
#              artist           song  \
# 57644  Ziggy Marley     Generation
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57644     /z/ziggy+marley/generation_20531171.html
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57644  Many generation have passed away  \r\nFighting...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df = pd.read_csv("spotify_millsongdata.csv")

text = ' '.join(df['text'].values)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Song Texts')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv("spotify_millsongdata.csv")

# Get top artists
top_artists = df['artist'].value_counts()[:10]

# Plot top artists
plt.figure(figsize=(10, 6))
top_artists.plot(kind='bar')
plt.xlabel('Artist')
plt.ylabel('Number of Songs')
plt.title('Top Artists by Number of Songs')
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv("spotify_millsongdata.csv")

# Combine all lyrics
lyrics = ' '.join(df['text'])

# Count word frequencies
word_counts = Counter(lyrics.split())

# Get the top 10 most common words
common_words = word_counts.most_common(10)

# Separate words and their frequencies
labels, values = zip(*common_words)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(labels, values, color='lightcoral')
plt.xlabel('Frequency')
plt.title('Top Words in Song Lyrics')
plt.gca().invert_yaxis()
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv("spotify_millsongdata.csv")

# Combine all song titles
song_titles = ' '.join(df['song'])

# Count word frequencies
word_counts = Counter(song_titles.split())

# Get the top 10 most common words
common_words = word_counts.most_common(10)

# Separate words and their frequencies
labels, values = zip(*common_words)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(labels, values, color='lightsteelblue')
plt.xlabel('Frequency')
plt.title('Top Words in Song Titles')
plt.gca().invert_yaxis()
plt.show()

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df = df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#              artist                       song  \
# 0      Human League            Never Let Me Go
# 1         Helloween  I Don't Wanna Cry No More
# 2     Frank Sinatra          But None Like You
# 3      David Guetta                  Blast Off
# 4  Yngwie Malmsteen             Crash And Burn
# 5    Linda Ronstadt                  Heat Wave
# 6        Tim McGraw            Eyes Of A Woman
# 7       Dean Martin          A Million And One
# 8    Michael Bolton                  Breakaway
# 9      Foo Fighters             Gimme Stitches
#
#                                                 text
# 0  Go go go  \r\nGo go go  \r\n  \r\nLet me tell ...
# 1  Hey, brother  \r\nI miss you so  \r\nYou knock...
# 2  The world is full of people, but none like you...
# 3  This is a blast off  \r\nIt's time to blow thi...
# 4  The smoke has cleared  \r\nAnd I'm still stand...
# 5  Whenever I'm with him  \r\nSomething inside st...
# 6  He was rough he was tough  \r\nAnd he drank hi...
# ...

# %%
df['text'][0]
# Out:
# "Go go go  \r\nGo go go  \r\n  \r\nLet me tell you what you're doing wrong  \r\nBeen so far for years, well it's much too long  \r\nThere just has to be another way  \r\nIt will get you by going day to day  \r\nIf you need another point of view  \r\nTake a look at mine, I got something new  \r\nI got something new  \r\n  \r\nIt's for you  \r\nI hate you  \r\nThese things can quite endear you  \r\nI call you  \r\nI adore you  \r\nWon't let the world ignore you  \r\nGo go go  \r\n  \r\nI'm the one you want  \r\nI'm the one you need  \r\nNever let me go  \r\nNever let me go  \r\n[X4]  \r\n  \r\nGo go go  \r\n  \r\nThere's a mirror standing over there  \r\nTell me what you see, take a cold hard step  \r\nSave the people standing in the frame  \r\nTell me like our [?]  \r\nYou should try another point of view  \r\nTake a look at mine, but it's up to you  \r\nBut it's up to you  \r\n  \r\nIt's for you  \r\nJust for you  \r\nFrom one who must adore you  \r\nIn love fallen  \r\nI'm someone w
# ...

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# text cleaning

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
df.tail(5)
# Out:
#             artist            song  \
# 4995  Donna Summer       I Believe
# 4996    Supertramp  Free As A Bird
# 4997   Bryan White    Rebecca Lynn
# 4998     Metallica       Mama Said
# 4999   Chuck Berry     Havana Moon
#
#                                                    text
# 4995  i believe in you  \r if you believe in me  \r ...
# 4996  when a spirit is broken  \r why go on  \r when...
# 4997  rebecca lynn grew up in carolina  \r half a mi...
# 4998  mama she has taught me well  \r told me when i...
# 4999  havana moon, havana moon  \r me all alone with...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def token(txt):
    token = nltk.word_tokenize(txt)
    a = [stemmer.stem(w) for w in token]
    return " ".join(a)

# %%
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
import seaborn as sns

nltk.download('punkt')

stemmer = PorterStemmer()

def token(txt):
    tokens = nltk.word_tokenize(txt)
    stemmed_tokens = [stemmer.stem(w) for w in tokens]
    return stemmed_tokens

text = "This is a sample sentence. This sentence is for testing the frequency of stemmed words."

tokens = token(text)

freq_dist = FreqDist(tokens)

plt.figure(figsize=(10, 6))
sns.barplot(x=list(freq_dist.keys()), y=list(freq_dist.values()))

plt.title("Word Frequency Distribution of Stemmed Tokens")
plt.xlabel("Words")
plt.ylabel("Frequency")

plt.xticks(rotation=45)  # Rotate the words for better visibility
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
token("you are beautiful, beauty")
# Out:
# ['you', 'are', 'beauti', ',', 'beauti']

# %%
df['text'] = df['text'].apply(lambda x: token(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Convert list entries in 'text' column to strings if necessary
df['text'] = df['text'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

# Now apply TfidfVectorizer
tfid = TfidfVectorizer(analyzer='word', stop_words='english')
matrix = tfid.fit_transform(df['text'])
similar = cosine_similarity(matrix)

# %%
similar[1]
# Out:
# array([0.04407995, 1.        , 0.05840279, ..., 0.04443168, 0.05571853,
#        0.03117682])

# %%
df[df['song']=='Rebecca Lynn'].index[0]
# Out:
# 4997

# %%
def recommender(song_name):
        idx = df[df['song'] == song_name].index[0]
        distance = sorted(list(enumerate(similar[idx])), reverse=True, key=lambda x: x[1])
        song = []
        for i in distance[1:10]:  
            song.append(df.iloc[i[0]]['song'])
        return song

# %%
recommender("Rebecca Lynn")
# Out:
# ['Look Mama',
#  "Rose's Turn",
#  'Mama Africa',
#  'Leaving Town Blues',
#  'Let Me Go To The Show',
#  'Mama Why',
#  "Mama's Little Girl",
#  'Love Them Girls',
#  'I Got The Will']

# %%
import pickle

# %%
pickle.dump(similar, open("similarity","wb"))

# %%
pickle.dump(df, open("df","wb"))
